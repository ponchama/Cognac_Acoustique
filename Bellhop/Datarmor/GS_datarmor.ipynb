# %%
# this enable automatic reloading of libraries
# %load_ext autoreload
# %autoreload 2

# %matplotlib notebook
from clib.bellhop import *
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')
from matplotlib.animation import FuncAnimation

# %%
s = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', \
                    'file':10, 'itime':10, 'lon': -66.6, 'lat': 36., \
                    'plot_map': False, 'contour':False}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00260.nc
# Uses the following time : 10

# %% [markdown]
# ---
# ---
# # Initialisation of parameters

# %%
dire = '/home1/datawork/aponte/cognac/R0/'
Arr, Pos = s.read_arrivals_asc(dire+'OUT00/0_time0_10km.arr', Narrmx = 66)
# Out:
# Max.number of arrivals for source index 0 is 65

# %%
Nsd = np.shape(Pos['s']['depth'])[0]
Nrd = np.shape(Pos['r']['depth'])[0]
Nrr = np.shape(Pos['r']['range'])[0]
print('Number of source depths   : Nsd = ', Nsd)
print('Number of receiver depths : Nrd = ', Nrd)
print('Number of receiver ranges : Nrr = ', Nrr)
# Out:
# Number of source depths   : Nsd =  1
# Number of receiver depths : Nrd =  51
# Number of receiver ranges : Nrr =  101

# %%
### sonar equation
SL = 185                 # Souce level (dB)
NL = 81.7                # Noise level (dB)
DI = 0                   # Directivity index (dB)
B = 200                  # bandwidth (Hz)
T = 1                    # transmitted signal duration (s)
PG = 10.0*np.log10(B*T)  # Processing gain (dB)

#RT  = SL - TL - NL + DI + PG 
seuil_d = 10.

# %%
# Create time table from bellhop output data. Based on detection treshold method.
def time_table (Arr) :
    T = np.zeros( (Nrr, Nrd, Nsd) )
    for isd1 in range (Nsd):
        for ird1 in range (Nrd) : 
            for irr1 in range (Nrr) :
                Narr = int(Arr['Narr'][irr1, ird1, isd1])
                if not Narr ==0 :
                    A = abs(Arr['A'][irr1, :Narr, ird1, isd1])  # amplitude 
                    TL = - 20.0*np.log10(A)
                    RL = SL - TL - NL +DI + PG    # received level 
                    t = Arr['delay'][irr1, :Narr, ird1, isd1]
                    t_ok = t[np.where(RL > seuil_d)]

                    if len(t_ok > 0): 
                        t_min = np.min(t_ok)
                        T[irr1,ird1,isd1] = t_min  
                    else : 
                        T[irr1,ird1,isd1] = np.NaN
                else : 
                    T[irr1,ird1,isd1] = np.NaN
    return (T)

# %%
isd = 0    # source number (only 1 source here)
R = np.array(Pos['r']['range'])
Z = np.array(Pos['r']['depth'])

# %% [markdown]
# ---
# ---
# # Creation of matrix of results

# %%
### Tous les infos dans les noms de fichiers
nb_files = 65
nb_times = [0,11]
nb_dist = [np.NaN,50,10]

### Matrices contenant toutes les cartes d'erreurs (pour profils tous les 50 et 10 km)
MAT_50 = np.zeros((Z.size, R.size, nb_files*len(nb_times)))
MAT_10 = np.zeros((Z.size, R.size, nb_files*len(nb_times)))
L_name = []
time = []
n = -1

for i in range (nb_files):
    if len(str(i))==1 : 
        folder = 'OUT0'+str(i)
    else : 
        folder = 'OUT'+str(i)

    for j in range(len(nb_times)):
        n+=1
        print(n)
        time.append(20*i+nb_times[j])
        file0 = str(i)+'_time'+str(nb_times[j])
        L_name.append(file0+'.arr')
        print(L_name[n])
        Tables = np.zeros ((Z.size, R.size, len(nb_dist)))
        for k in range (len(nb_dist)) :
            if np.isnan(nb_dist[k]) : 
                file1=''
            else : 
                file1 = '_%skm'%str(nb_dist[k])
            path = folder+'/'+file0+file1+'.arr'
            ###
            Arr, Pos = s.read_arrivals_asc(dire+path, Narrmx = 479)
            T = time_table(Arr)
            Tables[:,:,k]=T[:,:,0].T
        
        diff_50 = Tables[:,:,1] - Tables[:,:,0]
        MAT_50[:,:,n] = diff_50
        diff_10 = Tables[:,:,2] - Tables[:,:,0]
        MAT_10[:,:,n] = diff_10
# Out:
# 0
# 0_time0.arr
# Max.number of arrivals for source index 0 is 478
# Max.number of arrivals for source index 0 is 86
# Max.number of arrivals for source index 0 is 65
# 1
# 0_time11.arr
# Max.number of arrivals for source index 0 is 811
# Max.number of arrivals for source index 0 is 36
# Max.number of arrivals for source index 0 is 120
# 2
# 1_time0.arr
# Max.number of arrivals for source index 0 is 725
# Max.number of arrivals for source index 0 is 44
# Max.number of arrivals for source index 0 is 94
# 3
# 1_time11.arr
# Max.number of arrivals for source index 0 is 854
# Max.number of arrivals for source index 0 is 68
# Max.number of arrivals for source index 0 is 122
# 4
# 2_time0.arr
# Max.number of arrivals for source index 0 is 709
# Max.number of arrivals for source index 0 is 128
# Max.number of arrivals for source index 0 is 129
# 5
# 2_time11.arr
# Max.number of arrivals for source index 0 is 568
# Max.number of arrivals for source index 0 is 62
# Max.number of arrivals for source index 0 is 132
# 6
# 3_time0.arr
# Max.number of arrivals for source index 0 is 539
# Max.number of arrivals for source index 0 is 39
# Max.number of arrivals for source index 0 is 73
# 7
# 3_time11.arr
# Max.number of arrivals for source index 0 is 527
# Max.number of arrivals for source index 0 is 95
# Max.number of arrivals for source index 0 is 61
# 8
# 4_time0.arr
# Max.number of arrivals for source index 0 is 518
# Max.number of arrivals for source index 0 is 60
# Max.number of arrivals for source index 0 is 137
# 9
# 4_time11.arr
# Max.number of arrivals for source index 0 is 327
# Max.number of arrivals for source index 0 is 40
# Max.number of arrivals for source index 0 is 157
# 10
# 5_time0.arr
# Max.number of arrivals for source index 0 is 450
# Max.number of arrivals for source index 0 is 64
# Max.number of arrivals for source index 0 is 95
# 11
# 5_time11.arr
# Max.number of arrivals for source index 0 is 279
# Max.number of arrivals for source index 0 is 38
# Max.number of arrivals for source index 0 is 89
# 12
# 6_time0.arr
# Max.number of arrivals for source index 0 is 422
# Max.number of arrivals for source index 0 is 43
# Max.number of arrivals for source index 0 is 145
# 13
# 6_time11.arr
# Max.number of arrivals for source index 0 is 355
# Max.number of arrivals for source index 0 is 44
# Max.number of arrivals for source index 0 is 107
# 14
# 7_time0.arr
# Max.number of arrivals for source index 0 is 402
# Max.number of arrivals for source index 0 is 43
# Max.number of arrivals for source index 0 is 126
# 15
# 7_time11.arr
# Max.number of arrivals for source index 0 is 230
# Max.number of arrivals for source index 0 is 44
# Max.number of arrivals for source index 0 is 67
# 16
# 8_time0.arr
# Max.number of arrivals for source index 0 is 734
# Max.number of arrivals for source index 0 is 38
# Max.number of arrivals for source index 0 is 83
# 17
# 8_time11.arr
# Max.number of arrivals for source index 0 is 790
# Max.number of arrivals for source index 0 is 41
# Max.number of arrivals for source index 0 is 68
# 18
# 9_time0.arr
# Max.number of arrivals for source index 0 is 525
# Max.number of arrivals for source index 0 is 45
# Max.number of arrivals for source index 0 is 71
# 19
# 9_time11.arr
# Max.number of arrivals for source index 0 is 517
# Max.number of arrivals for source index 0 is 45
# Max.number of arrivals for source index 0 is 55
# 20
# 10_time0.arr
# Max.number of arrivals for source index 0 is 555
# Max.number of arrivals for source index 0 is 49
# Max.number of arrivals for source index 0 is 57
# 21
# 10_time11.arr
# Max.number of arrivals for source index 0 is 386
# Max.number of arrivals for source index 0 is 48
# Max.number of arrivals for source index 0 is 57
# 22
# 11_time0.arr
# Max.number of arrivals for source index 0 is 738
# Max.number of arrivals for source index 0 is 54
# Max.number of arrivals for source index 0 is 44
# 23
# 11_time11.arr
# Max.number of arrivals for source index 0 is 360
# Max.number of arrivals for source index 0 is 45
# Max.number of arrivals for source index 0 is 49
# 24
# 12_time0.arr
# Max.number of arrivals for source index 0 is 496
# Max.number of arrivals for source index 0 is 48
# Max.number of arrivals for source index 0 is 68
# 25
# 12_time11.arr
# Max.number of arrivals for source index 0 is 517
# Max.number of arrivals for source index 0 is 48
# Max.number of arrivals for source index 0 is 44
# 26
# 13_time0.arr
# Max.number of arrivals for source index 0 is 471
# Max.number of arrivals for source index 0 is 53
# Max.number of arrivals for source index 0 is 63
# 27
# 13_time11.arr
# Max.number of arrivals for source index 0 is 513
# Max.number of arrivals for source index 0 is 51
# Max.number of arrivals for source index 0 is 46
# 28
# 14_time0.arr
# Max.number of arrivals for source index 0 is 404
# Max.number of arrivals for source index 0 is 48
# Max.number of arrivals for source index 0 is 46
# 29
# 14_time11.arr
# Max.number of arrivals for source index 0 is 513
# Max.number of arrivals for source index 0 is 46
# Max.number of arrivals for source index 0 is 50
# 30
# 15_time0.arr
# Max.number of arrivals for source index 0 is 430
# Max.number of arrivals for source index 0 is 51
# Max.number of arrivals for source index 0 is 43
# 31
# 15_time11.arr
# Max.number of arrivals for source index 0 is 386
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 45
# 32
# 16_time0.arr
# Max.number of arrivals for source index 0 is 447
# Max.number of arrivals for source index 0 is 55
# Max.number of arrivals for source index 0 is 46
# 33
# 16_time11.arr
# Max.number of arrivals for source index 0 is 618
# Max.number of arrivals for source index 0 is 48
# Max.number of arrivals for source index 0 is 53
# 34
# 17_time0.arr
# Max.number of arrivals for source index 0 is 774
# Max.number of arrivals for source index 0 is 63
# Max.number of arrivals for source index 0 is 63
# 35
# 17_time11.arr
# Max.number of arrivals for source index 0 is 690
# Max.number of arrivals for source index 0 is 59
# Max.number of arrivals for source index 0 is 62
# 36
# 18_time0.arr
# Max.number of arrivals for source index 0 is 670
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 52
# 37
# 18_time11.arr
# Max.number of arrivals for source index 0 is 505
# Max.number of arrivals for source index 0 is 50
# Max.number of arrivals for source index 0 is 55
# 38
# 19_time0.arr
# Max.number of arrivals for source index 0 is 575
# Max.number of arrivals for source index 0 is 41
# Max.number of arrivals for source index 0 is 55
# 39
# 19_time11.arr
# Max.number of arrivals for source index 0 is 860
# Max.number of arrivals for source index 0 is 49
# Max.number of arrivals for source index 0 is 72
# 40
# 20_time0.arr
# Max.number of arrivals for source index 0 is 506
# Max.number of arrivals for source index 0 is 50
# Max.number of arrivals for source index 0 is 146
# 41
# 20_time11.arr
# Max.number of arrivals for source index 0 is 981
# Max.number of arrivals for source index 0 is 57
# Max.number of arrivals for source index 0 is 202
# 42
# 21_time0.arr
# Max.number of arrivals for source index 0 is 416
# Max.number of arrivals for source index 0 is 24
# Max.number of arrivals for source index 0 is 81
# 43
# 21_time11.arr
# Max.number of arrivals for source index 0 is 153
# Max.number of arrivals for source index 0 is 33
# Max.number of arrivals for source index 0 is 47
# 44
# 22_time0.arr
# Max.number of arrivals for source index 0 is 100
# Max.number of arrivals for source index 0 is 22
# Max.number of arrivals for source index 0 is 84
# 45
# 22_time11.arr
# Max.number of arrivals for source index 0 is 149
# Max.number of arrivals for source index 0 is 40
# Max.number of arrivals for source index 0 is 62
# 46
# 23_time0.arr
# Max.number of arrivals for source index 0 is 212
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 101
# 47
# 23_time11.arr
# Max.number of arrivals for source index 0 is 763
# Max.number of arrivals for source index 0 is 41
# Max.number of arrivals for source index 0 is 220
# 48
# 24_time0.arr
# Max.number of arrivals for source index 0 is 458
# Max.number of arrivals for source index 0 is 51
# Max.number of arrivals for source index 0 is 176
# 49
# 24_time11.arr
# Max.number of arrivals for source index 0 is 650
# Max.number of arrivals for source index 0 is 49
# Max.number of arrivals for source index 0 is 132
# 50
# 25_time0.arr
# Max.number of arrivals for source index 0 is 435
# Max.number of arrivals for source index 0 is 51
# Max.number of arrivals for source index 0 is 91
# 51
# 25_time11.arr
# Max.number of arrivals for source index 0 is 634
# Max.number of arrivals for source index 0 is 71
# Max.number of arrivals for source index 0 is 145
# 52
# 26_time0.arr
# Max.number of arrivals for source index 0 is 259
# Max.number of arrivals for source index 0 is 65
# Max.number of arrivals for source index 0 is 126
# 53
# 26_time11.arr
# Max.number of arrivals for source index 0 is 492
# Max.number of arrivals for source index 0 is 62
# Max.number of arrivals for source index 0 is 93
# 54
# 27_time0.arr
# Max.number of arrivals for source index 0 is 520
# Max.number of arrivals for source index 0 is 44
# Max.number of arrivals for source index 0 is 62
# 55
# 27_time11.arr
# Max.number of arrivals for source index 0 is 325
# Max.number of arrivals for source index 0 is 84
# Max.number of arrivals for source index 0 is 66
# 56
# 28_time0.arr
# Max.number of arrivals for source index 0 is 680
# Max.number of arrivals for source index 0 is 59
# Max.number of arrivals for source index 0 is 55
# 57
# 28_time11.arr
# Max.number of arrivals for source index 0 is 703
# Max.number of arrivals for source index 0 is 50
# Max.number of arrivals for source index 0 is 37
# 58
# 29_time0.arr
# Max.number of arrivals for source index 0 is 575
# Max.number of arrivals for source index 0 is 71
# Max.number of arrivals for source index 0 is 57
# 59
# 29_time11.arr
# Max.number of arrivals for source index 0 is 422
# Max.number of arrivals for source index 0 is 50
# Max.number of arrivals for source index 0 is 45
# 60
# 30_time0.arr
# Max.number of arrivals for source index 0 is 454
# Max.number of arrivals for source index 0 is 42
# Max.number of arrivals for source index 0 is 55
# 61
# 30_time11.arr
# Max.number of arrivals for source index 0 is 568
# Max.number of arrivals for source index 0 is 53
# Max.number of arrivals for source index 0 is 76
# 62
# 31_time0.arr
# Max.number of arrivals for source index 0 is 569
# Max.number of arrivals for source index 0 is 42
# Max.number of arrivals for source index 0 is 46
# 63
# 31_time11.arr
# Max.number of arrivals for source index 0 is 551
# Max.number of arrivals for source index 0 is 54
# Max.number of arrivals for source index 0 is 49
# 64
# 32_time0.arr
# Max.number of arrivals for source index 0 is 517
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 43
# 65
# 32_time11.arr
# Max.number of arrivals for source index 0 is 664
# Max.number of arrivals for source index 0 is 41
# Max.number of arrivals for source index 0 is 54
# 66
# 33_time0.arr
# Max.number of arrivals for source index 0 is 339
# Max.number of arrivals for source index 0 is 54
# Max.number of arrivals for source index 0 is 64
# 67
# 33_time11.arr
# Max.number of arrivals for source index 0 is 427
# Max.number of arrivals for source index 0 is 55
# Max.number of arrivals for source index 0 is 42
# 68
# 34_time0.arr
# Max.number of arrivals for source index 0 is 428
# Max.number of arrivals for source index 0 is 46
# Max.number of arrivals for source index 0 is 44
# 69
# 34_time11.arr
# Max.number of arrivals for source index 0 is 587
# Max.number of arrivals for source index 0 is 60
# Max.number of arrivals for source index 0 is 54
# 70
# 35_time0.arr
# Max.number of arrivals for source index 0 is 467
# Max.number of arrivals for source index 0 is 106
# Max.number of arrivals for source index 0 is 41
# 71
# 35_time11.arr
# Max.number of arrivals for source index 0 is 617
# Max.number of arrivals for source index 0 is 137
# Max.number of arrivals for source index 0 is 49
# 72
# 36_time0.arr
# Max.number of arrivals for source index 0 is 668
# Max.number of arrivals for source index 0 is 94
# Max.number of arrivals for source index 0 is 48
# 73
# 36_time11.arr
# Max.number of arrivals for source index 0 is 806
# Max.number of arrivals for source index 0 is 127
# Max.number of arrivals for source index 0 is 89
# 74
# 37_time0.arr
# Max.number of arrivals for source index 0 is 877
# Max.number of arrivals for source index 0 is 103
# Max.number of arrivals for source index 0 is 241
# 75
# 37_time11.arr
# Max.number of arrivals for source index 0 is 702
# Max.number of arrivals for source index 0 is 147
# Max.number of arrivals for source index 0 is 75
# 76
# 38_time0.arr
# Max.number of arrivals for source index 0 is 537
# Max.number of arrivals for source index 0 is 85
# Max.number of arrivals for source index 0 is 64
# 77
# 38_time11.arr
# Max.number of arrivals for source index 0 is 571
# Max.number of arrivals for source index 0 is 48
# Max.number of arrivals for source index 0 is 61
# 78
# 39_time0.arr
# Max.number of arrivals for source index 0 is 436
# Max.number of arrivals for source index 0 is 51
# Max.number of arrivals for source index 0 is 49
# 79
# 39_time11.arr
# Max.number of arrivals for source index 0 is 471
# Max.number of arrivals for source index 0 is 49
# Max.number of arrivals for source index 0 is 54
# 80
# 40_time0.arr
# Max.number of arrivals for source index 0 is 282
# Max.number of arrivals for source index 0 is 54
# Max.number of arrivals for source index 0 is 54
# 81
# 40_time11.arr
# Max.number of arrivals for source index 0 is 474
# Max.number of arrivals for source index 0 is 48
# Max.number of arrivals for source index 0 is 52
# 82
# 41_time0.arr
# Max.number of arrivals for source index 0 is 489
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 64
# 83
# 41_time11.arr
# Max.number of arrivals for source index 0 is 571
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 53
# 84
# 42_time0.arr
# Max.number of arrivals for source index 0 is 577
# Max.number of arrivals for source index 0 is 51
# Max.number of arrivals for source index 0 is 58
# 85
# 42_time11.arr
# Max.number of arrivals for source index 0 is 427
# Max.number of arrivals for source index 0 is 72
# Max.number of arrivals for source index 0 is 71
# 86
# 43_time0.arr
# Max.number of arrivals for source index 0 is 357
# Max.number of arrivals for source index 0 is 27
# Max.number of arrivals for source index 0 is 82
# 87
# 43_time11.arr
# Max.number of arrivals for source index 0 is 84
# Max.number of arrivals for source index 0 is 32
# Max.number of arrivals for source index 0 is 25
# 88
# 44_time0.arr
# Max.number of arrivals for source index 0 is 203
# Max.number of arrivals for source index 0 is 144
# Max.number of arrivals for source index 0 is 271
# 89
# 44_time11.arr
# Max.number of arrivals for source index 0 is 276
# Max.number of arrivals for source index 0 is 233
# Max.number of arrivals for source index 0 is 201
# 90
# 45_time0.arr
# Max.number of arrivals for source index 0 is 661
# Max.number of arrivals for source index 0 is 112
# Max.number of arrivals for source index 0 is 221
# 91
# 45_time11.arr
# Max.number of arrivals for source index 0 is 416
# Max.number of arrivals for source index 0 is 113
# Max.number of arrivals for source index 0 is 289
# 92
# 46_time0.arr
# Max.number of arrivals for source index 0 is 322
# Max.number of arrivals for source index 0 is 37
# Max.number of arrivals for source index 0 is 41
# 93
# 46_time11.arr
# Max.number of arrivals for source index 0 is 243
# Max.number of arrivals for source index 0 is 42
# Max.number of arrivals for source index 0 is 283
# 94
# 47_time0.arr
# Max.number of arrivals for source index 0 is 235
# Max.number of arrivals for source index 0 is 31
# Max.number of arrivals for source index 0 is 170
# 95
# 47_time11.arr
# Max.number of arrivals for source index 0 is 427
# Max.number of arrivals for source index 0 is 64
# Max.number of arrivals for source index 0 is 78
# 96
# 48_time0.arr
# Max.number of arrivals for source index 0 is 409
# Max.number of arrivals for source index 0 is 70
# Max.number of arrivals for source index 0 is 115
# 97
# 48_time11.arr
# Max.number of arrivals for source index 0 is 607
# Max.number of arrivals for source index 0 is 56
# Max.number of arrivals for source index 0 is 198
# 98
# 49_time0.arr
# Max.number of arrivals for source index 0 is 216
# Max.number of arrivals for source index 0 is 40
# Max.number of arrivals for source index 0 is 138
# 99
# 49_time11.arr
# Max.number of arrivals for source index 0 is 781
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 116
# 100
# 50_time0.arr
# Max.number of arrivals for source index 0 is 791
# Max.number of arrivals for source index 0 is 55
# Max.number of arrivals for source index 0 is 109
# 101
# 50_time11.arr
# Max.number of arrivals for source index 0 is 845
# Max.number of arrivals for source index 0 is 82
# Max.number of arrivals for source index 0 is 325
# 102
# 51_time0.arr
# Max.number of arrivals for source index 0 is 853
# Max.number of arrivals for source index 0 is 113
# Max.number of arrivals for source index 0 is 170
# 103
# 51_time11.arr
# Max.number of arrivals for source index 0 is 964
# Max.number of arrivals for source index 0 is 62
# Max.number of arrivals for source index 0 is 135
# 104
# 52_time0.arr
# Max.number of arrivals for source index 0 is 563
# Max.number of arrivals for source index 0 is 61
# Max.number of arrivals for source index 0 is 105
# 105
# 52_time11.arr
# Max.number of arrivals for source index 0 is 487
# Max.number of arrivals for source index 0 is 61
# Max.number of arrivals for source index 0 is 268
# 106
# 53_time0.arr
# Max.number of arrivals for source index 0 is 729
# Max.number of arrivals for source index 0 is 68
# Max.number of arrivals for source index 0 is 359
# 107
# 53_time11.arr
# Max.number of arrivals for source index 0 is 800
# Max.number of arrivals for source index 0 is 93
# Max.number of arrivals for source index 0 is 307
# 108
# 54_time0.arr
# Max.number of arrivals for source index 0 is 563
# Max.number of arrivals for source index 0 is 108
# Max.number of arrivals for source index 0 is 321
# 109
# 54_time11.arr
# Max.number of arrivals for source index 0 is 330
# Max.number of arrivals for source index 0 is 222
# Max.number of arrivals for source index 0 is 133
# 110
# 55_time0.arr
# Max.number of arrivals for source index 0 is 524
# Max.number of arrivals for source index 0 is 105
# Max.number of arrivals for source index 0 is 139
# 111
# 55_time11.arr
# Max.number of arrivals for source index 0 is 536
# Max.number of arrivals for source index 0 is 113
# Max.number of arrivals for source index 0 is 132
# 112
# 56_time0.arr
# Max.number of arrivals for source index 0 is 455
# Max.number of arrivals for source index 0 is 94
# Max.number of arrivals for source index 0 is 132
# 113
# 56_time11.arr
# Max.number of arrivals for source index 0 is 479
# Max.number of arrivals for source index 0 is 161
# Max.number of arrivals for source index 0 is 64
# 114
# 57_time0.arr
# Max.number of arrivals for source index 0 is 404
# Max.number of arrivals for source index 0 is 52
# Max.number of arrivals for source index 0 is 89
# 115
# 57_time11.arr
# Max.number of arrivals for source index 0 is 580
# Max.number of arrivals for source index 0 is 40
# Max.number of arrivals for source index 0 is 55
# 116
# 58_time0.arr
# Max.number of arrivals for source index 0 is 533
# Max.number of arrivals for source index 0 is 50
# Max.number of arrivals for source index 0 is 52
# 117
# 58_time11.arr
# Max.number of arrivals for source index 0 is 690
# Max.number of arrivals for source index 0 is 76
# Max.number of arrivals for source index 0 is 81
# 118
# 59_time0.arr
# Max.number of arrivals for source index 0 is 723
# Max.number of arrivals for source index 0 is 56
# Max.number of arrivals for source index 0 is 80
# 119
# 59_time11.arr
# Max.number of arrivals for source index 0 is 639
# Max.number of arrivals for source index 0 is 47
# Max.number of arrivals for source index 0 is 59
# 120
# 60_time0.arr
# Max.number of arrivals for source index 0 is 700
# Max.number of arrivals for source index 0 is 40
# Max.number of arrivals for source index 0 is 88
# 121
# 60_time11.arr
# Max.number of arrivals for source index 0 is 338
# Max.number of arrivals for source index 0 is 29
# Max.number of arrivals for source index 0 is 27
# 122
# 61_time0.arr
# Max.number of arrivals for source index 0 is 111
# Max.number of arrivals for source index 0 is 29
# Max.number of arrivals for source index 0 is 56
# 123
# 61_time11.arr
# Max.number of arrivals for source index 0 is 242
# Max.number of arrivals for source index 0 is 46
# Max.number of arrivals for source index 0 is 241
# 124
# 62_time0.arr
# Max.number of arrivals for source index 0 is 294
# Max.number of arrivals for source index 0 is 71
# Max.number of arrivals for source index 0 is 373
# 125
# 62_time11.arr
# Max.number of arrivals for source index 0 is 253
# Max.number of arrivals for source index 0 is 44
# Max.number of arrivals for source index 0 is 112
# 126
# 63_time0.arr
# Max.number of arrivals for source index 0 is 689
# Max.number of arrivals for source index 0 is 42
# Max.number of arrivals for source index 0 is 244
# 127
# 63_time11.arr
# Max.number of arrivals for source index 0 is 864
# Max.number of arrivals for source index 0 is 110
# Max.number of arrivals for source index 0 is 399
# 128
# 64_time0.arr
# Max.number of arrivals for source index 0 is 387
# Max.number of arrivals for source index 0 is 25
# Max.number of arrivals for source index 0 is 92
# 129
# 64_time11.arr
# Max.number of arrivals for source index 0 is 32
# Max.number of arrivals for source index 0 is 23
# Max.number of arrivals for source index 0 is 22

# %% [markdown]
# ---
# ---
# # Animations

# %% [markdown]
# - https://github.com/markjay4k/fourier-transform/blob/master/Animated%20Sinc%20and%20FT%20example.ipynb
# - https://brushingupscience.com/2016/06/21/matplotlib-animations-the-easy-way/

# %%
### Animation
fig, ax = plt.subplots(figsize=(7, 4))
ax.set(xlim=(0., 100.), ylim=(0., 500.))
   
cax = ax.pcolormesh(R/1000., Z, MAT_50[:, :, 0]*1500., vmin=0., vmax=300.)
cbar = fig.colorbar(cax)
plt.gca().invert_yaxis()
plt.xlabel('range (km)')
plt.ylabel('depth (m)')
cbar.set_label("error(m)")
    
def animate(i):
    cax.set_array((MAT_50[:-1,:-1,i]*1500.).flatten())
    plt.title('Error on position - 1 profile every 50km: %dh = %.2fjours' %(time[i],\
                                                                        time[i]/24.))

anim = FuncAnimation(fig, animate, interval=5.e2, frames=MAT_50.shape[2])
plt.draw()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.9666666666667">

# %%
### Animation
fig, ax = plt.subplots(figsize=(7, 4))
ax.set(xlim=(0., 100.), ylim=(0., 500.))
   
cax = ax.pcolormesh(R/1000., Z, MAT_10[:, :, 0]*1500., vmin=0., vmax=300.)
cbar = fig.colorbar(cax)
plt.gca().invert_yaxis()
plt.xlabel('range (km)')
plt.ylabel('depth (m)')
cbar.set_label("error(m)")
    
def animate(i):
    cax.set_array((MAT_10[:-1,:-1,i]*1500.).flatten())
    plt.title('Error on position - 1 profile every 10km: %dh = %.2fjours' %(time[i],\
                                                                        time[i]/24.))

anim = FuncAnimation(fig, animate, interval=5.e2, frames=MAT_10.shape[2])
plt.draw()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.9666666666667">

# %%
# export the animation
#anim.save('error_profile_10km.gif', writer='imagemagick')

# %% [markdown]
# ---
# ---
# # Mean error

# %%
err_moy = np.zeros((Z.size, R.size))
for i in range (MAT_50.shape[2]):
    err_moy += (MAT_50[:,:,i]*1500.)
err_moy50 = err_moy/MAT_50.shape[2]

err_moy = np.zeros((Z.size, R.size))
for i in range (MAT_10.shape[2]):
    err_moy += (MAT_10[:,:,i]*1500.)
err_moy10 = err_moy/MAT_10.shape[2]

#plot
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.pcolormesh(R/1000., Z, err_moy50, vmin=0., vmax=300.)
cbar = plt.colorbar()
plt.gca().invert_yaxis()
plt.xlabel('range (km)')
plt.ylabel('depth (m)')
plt.title('Mean error - 1 profile every 50km')
cbar.set_label("error(m)")

plt.subplot(122)
plt.pcolormesh(R/1000., Z, err_moy10, vmin=0., vmax=300.)
cbar = plt.colorbar()
plt.gca().invert_yaxis()
plt.xlabel('range (km)')
plt.ylabel('depth (m)')
plt.title('Mean error - 1 profile every 10km')
cbar.set_label("error(m)")
# Out:
# <img src="data:image/png;base64,..." width="1199.8333333333333">

# %%
# moyenne en chaque point (65valeurs), puis moyenne du résultats sur la grille
print('50 km : mean (erreur) = %.1fm' %np.mean(err_moy50[~np.isnan(err_moy50)]))
print('        max (erreur)  = %.1fm' %np.max(err_moy50[~np.isnan(err_moy50)]))
# Out:
# 50 km : mean (erreur) = 285.0m
#         max (erreur)  = 1248.7m

# %%
print('10 km : mean (erreur) = %.1fm' %np.mean(err_moy10[~np.isnan(err_moy10)]))
print('        max (erreur)  = %.1fm' %np.max(err_moy10[~np.isnan(err_moy10)]))
# Out:
# 10 km : mean (erreur) = 203.8m
#         max (erreur)  = 921.7m

# %%
err_moy50.shape
# Out:
# (51, 101)

# %%
### Sur les 20 premiers km 
err = err_moy50[:,:20]
print(np.mean(err[~np.isnan(err)]))
print(np.max(err[~np.isnan(err)]))
# Out:
# 38.91250518030484
# 548.2549361538463

# %%
### Faire la même chose avec la rms : valeur moyenne calculée ci-dessus
#rms = np.sqrt( np.mean( (x - r.x)**2 ) )

# %% [markdown]
# ---
# ---
# ---
#
#
# # Profils de célérité 2D

# %%
### Tous les infos dans les noms de fichiers
nb_files = 65
nb_times = [0,11]
nb_dist = [np.NaN,50,10]

### Define matrix size
path = dire +'OUT00/0_time0.ssp'
#'/home1/datawork/aponte/cognac/R0/OUT00/0_time0.ssp'
r_prof, d_prof, cmat = s.plotssp2D(path, plot=False)
zoom = 550
d_prof = d_prof[np.where(d_prof <= zoom)]
r_size = r_prof.size
d_size = d_prof.size

### Matrices contenant toutes les cartes d'erreurs (pour profils tous les 50 et 10 km)
MAT_prof = np.zeros((d_size, r_size, nb_files*len(nb_times)))
L_name = []
time = []
n = -1

for i in range (nb_files):
    if len(str(i))==1 : 
        folder = 'OUT0'+str(i)
    else : 
        folder = 'OUT'+str(i)
    for j in range(len(nb_times)):
        n+=1
        time.append(20*i+nb_times[j])
        file0 = str(i)+'_time'+str(nb_times[j])
        L_name.append(file0+'.ssp')
        #
        path = dire+folder+'/'+file0+'.ssp'
        r_prof, d_prof, cmat = s.plotssp2D(path, plot=False)
        d_prof = d_prof[np.where(d_prof <= zoom)]
        cmat = cmat[np.where(d_prof <= zoom)]
        #
        MAT_prof[:,:,n] = cmat

# %%
### Animation
fig, ax = plt.subplots(figsize=(7, 4))
ax.set(xlim=(0., 105.), ylim=(0., 500.))
   
cax = ax.pcolormesh(r_prof, d_prof, MAT_prof[:, :, 0], vmin=1515, vmax=1530)
cbar = fig.colorbar(cax)
plt.gca().invert_yaxis()
plt.xlabel('range (km)')
plt.ylabel('depth (m)')
cbar.set_label("celerity (m/s)")
    
def animate(i):
    cax.set_array((MAT_prof[:-1,:-1,i]).flatten())
    plt.title('Celerity profiles - %dh = %.2fjours' %(time[i], time[i]/24.))

anim = FuncAnimation(fig, animate, interval=5.e2, frames=MAT_prof.shape[2])
plt.draw()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="535.9">

# %%
# export the animation
#anim.save('celerity_profiles.gif', writer='imagemagick')
