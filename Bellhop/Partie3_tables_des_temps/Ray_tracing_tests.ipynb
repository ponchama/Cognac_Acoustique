# %%
# this enable automatic reloading of libraries
# %load_ext autoreload
# %autoreload 2

from clib.bellhop import *
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
s = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', 'lon': -66.6, \
                    'lat': 36., 'plot_map': False, 'contour':False}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00060.nc
# Uses the following time : 0

# %%
plt.figure(figsize=(8,5))
plt.subplot(111)
s.plotray('tests/gs_1prof_R.ray', zoom=False)
plt.title('Ray tracing - step by default', fontsize=16)
plt.xlabel('range (km)', fontsize=14)
plt.ylabel('depth (m)', fontsize=14)

plt.savefig('step_auto', dpi=100)

# %%
plt.figure(figsize=(8,5))
plt.subplot(111)
s.plotray('gs_1prof_R.ray', zoom=False)
plt.title('Ray tracing - step 10m', fontsize=16)
plt.xlabel('range (km)', fontsize=14)
plt.ylabel('depth (m)', fontsize=14)
plt.savefig('step_10m', dpi=100)

# %%
### Exemple bellhop (profil de Munk)
plt.figure(figsize=(10,8))
plt.subplot(111)
s.plotray('munk.ray', zoom=False)
plt.title('Munk')


#plt.savefig('Cubic_spline', dpi=100)
# Out:
# Text(0.5,1,'Munk')

# %%
plt.figure(figsize=(14,8))
plt.subplot(111)
s.plotray('tests/med_SSP1_R.ray', zoom=False)
plt.title('SSP1 Méditerranée')
plt.xlim([0.,70.])
plt.ylim([-500.,0.])
# Out:
# (-500.0, 0.0)

# %%
plt.figure(figsize=(10,8))
plt.subplot(111)
s.plotray('tests/prof_hiver.ray', zoom=False)
plt.title('Profil hiver parfait')
plt.xlim([0,20.])
plt.ylim([-300.,0.])
# Out:
# (-300.0, 0.0)

# %%
plt.figure(figsize=(10,8))
plt.subplot(111)
s.plotray('tests/isocel.ray', zoom=False)
plt.title('Profil constant parfait')
#plt.xlim([0,0.20])
#plt.ylim([-200.,0.])
# Out:
# Text(0.5,1,'Profil constant parfait')
