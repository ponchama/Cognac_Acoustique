# %%
# this enable automatic reloading of libraries
# %load_ext autoreload
# %autoreload 2

from clib.flow import *
from clib.bellhop import *
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ---
#
# # 1D SSP

# %%
s = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', 'lon': -66.6, \
                    'lat': 36., 'plot_map': True}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00060.nc

# %%
s.SSP['gs']['depth']
# Out:
# array([2.39244599e+00, 8.45041516e+00, 1.49110502e+01, 2.17898311e+01,
#        2.91103405e+01, 3.69046962e+01, 4.52141667e+01, 5.40899175e+01,
#        6.35939624e+01, 7.38002964e+01, 8.47962367e+01, 9.66840067e+01,
#        1.09582508e+02, 1.23629451e+02, 1.38983679e+02, 1.55827866e+02,
#        1.74371521e+02, 1.94854281e+02, 2.17549687e+02, 2.42769168e+02,
#        2.70866437e+02, 3.02242116e+02, 3.37348674e+02, 3.76695390e+02,
#        4.20853323e+02, 4.70459919e+02, 5.26223010e+02, 5.88923893e+02,
#        6.59418266e+02, 7.38635334e+02, 8.27572957e+02, 9.27288356e+02,
#        1.03888252e+03, 1.16347661e+03, 1.30217893e+03, 1.45603909e+03,
#        1.62598896e+03, 1.81276662e+03, 2.01682515e+03, 2.23822343e+03,
#        2.47650471e+03, 2.73056677e+03, 2.99853472e+03, 3.27765410e+03,
#        3.56422042e+03, 3.85357997e+03, 4.14022243e+03, 4.41799856e+03,
#        4.68047685e+03, 4.92143530e+03])

# %%
plt.plot(s.SSP['gs']['c'], -s.SSP['gs']['depth'])
#s.plotssp('gs')

# %% [markdown]
# ---
#
# # SSP 2D: transect

# %%
s = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', \
                    'lon': [-66.6, -65.6], 'lat': [36., 36.], 'plot_map': True}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00060.nc
# The transect will contain 179 horizontal points

# %%
d, depth = np.meshgrid(s.SSP['gs']['s'], s.SSP['gs']['depth'])

plt.pcolormesh(d, -depth, s.SSP['gs']['c'].T)
plt.colorbar()
