# %%
# this enable automatic reloading of libraries
# %load_ext autoreload
# %autoreload 2

from clib.bellhop import *
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
s = bellhop({'mediterrannee': './SSP_4profils.mat'},name='cognac_2000m_test',rmax=50.)

# %% [markdown]
# # SSP1

# %%
issp = 0     # sound speed profile number
s.plotssp('mediterrannee', Issp=issp)

# %%
### read file .arr 
#Arr1, Pos1 = s.read_arrivals_asc ('files_arr/cognac_2000m_test_A_full.arr', Narrmx = 15)
#s.save_dict('Dictio', Arr1, 'Arr1')
#s.save_dict('Dictio', Pos1, 'Pos1')

### reload saved dictionaries 
Arr1, Pos1 = s.load_dict('Dictio', 'Arr1'), s.load_dict('Dictio', 'Pos1')

# %%
Nsd = np.shape(Pos1['s']['depth'])[0]
Nrd = np.shape(Pos1['r']['depth'])[0]
Nrr = np.shape(Pos1['r']['range'])[0]

print('Number of source depths   : Nsd = ', Nsd)
print('Number of receiver depths : Nrd = ', Nrd)
print('Number of receiver ranges : Nrr = ', Nrr)

print ('\nTotal number of receivers : ', Nrr*Nrd)
# Out:
# Number of source depths   : Nsd =  1
# Number of receiver depths : Nrd =  501
# Number of receiver ranges : Nrr =  10001
#
# Total number of receivers :  5010501

# %% [markdown]
# ### Maximum amplitude

# %%
#Dir1, Nb_ref1 = s.direct(Nrr, Nrd, Nsd, Pos1, Arr1)
#np.save(os.path.join('NPY', 'Dir_SSP1'), Dir1)
#np.save(os.path.join('NPY', 'Nb_ref_SSP1'), Nb_ref1)
Dir1 = np.load('NPY/Dir_SSP1.npy')

# %%
s.plot_direct(Pos1, Dir1)

# %% [markdown]
# ### First detected arrival

# %%
RL1_first, Dir1_first, Nb_ref1_first = s.direct_first_arr(Nrr, Nrd, Nsd, Pos1, Arr1, treshold = 10.)
np.save(os.path.join('NPY', 'RL_first_SSP1'), RL1_first)
np.save(os.path.join('NPY', 'Dir_first_SSP1'), Dir1_first)
np.save(os.path.join('NPY', 'Nb_ref_first_SSP1'), Nb_ref1_first)
#Dir1_first = np.load('NPY/Dir_first_SSP1.npy')

# %%
s.plot_direct(Pos1, Dir1_first)

# %% [markdown]
# # SSP2

# %%
issp = 1     # sound speed profile number
s.plotssp('mediterrannee', Issp=issp)

# %%
#### read file .arr 
#Arr2, Pos2 = s.read_arrivals_asc ('files_arr/cognac_2000m_test_A_full_SSP2.arr', Narrmx = 15)
#s.save_dict('Dictio', Arr2, 'Arr2')
#s.save_dict('Dictio', Pos2, 'Pos2')

### reload saved dictionaries 
Arr2, Pos2 = s.load_dict('Dictio', 'Arr2'), s.load_dict('Dictio', 'Pos2')

# %%
Nsd = np.shape(Pos2['s']['depth'])[0]
Nrd = np.shape(Pos2['r']['depth'])[0]
Nrr = np.shape(Pos2['r']['range'])[0]
print ('\nTotal number of receivers : ', Nrr*Nrd)
# Out:
# Total number of receivers :  5010501

# %% [markdown]
# ### Maximum amplitude

# %%
#Dir2, Nb_ref2 = s.direct(Nrr, Nrd, Nsd, Pos2, Arr2)
#np.save(os.path.join('NPY', 'Dir_SSP2'), Dir2)
#np.save(os.path.join('NPY', 'Nb_ref_SSP2'), Nb_ref2)
Dir2 = np.load('NPY/Dir_SSP2.npy')

# %%
s.plot_direct(Pos2, Dir2)

# %% [markdown]
# ### First detected arrival

# %%
#RL2_first, Dir2_first, Nb_ref2_first = s.direct_first_arr(Nrr, Nrd, Nsd, Pos2, Arr2, treshold = 10.)
#np.save(os.path.join('NPY', 'RL_first_SSP2'), RL2_first)
#np.save(os.path.join('NPY', 'Dir_first_SSP2'), Dir2_first)
#np.save(os.path.join('NPY', 'Nb_ref_first_SSP2'), Nb_ref2_first)
Dir2_first = np.load('NPY/Dir_first_SSP2.npy')

# %%
s.plot_direct(Pos2, Dir2_first)

# %% [markdown]
# # SSP3

# %%
issp = 2     # sound speed profile number
s.plotssp('mediterrannee', Issp=issp)

# %%
#### read file .arr 
#Arr3, Pos3 = s.read_arrivals_asc ('files_arr/cognac_2000m_test_A_full_SSP3.arr', Narrmx = 15)
#s.save_dict('Dictio', Arr3, 'Arr3')
#s.save_dict('Dictio', Pos3, 'Pos3')

### reload saved dictionaries 
Arr3, Pos3 = s.load_dict('Dictio', 'Arr3'), s.load_dict('Dictio', 'Pos3')

# %%
Nsd = np.shape(Pos2['s']['depth'])[0]
Nrd = np.shape(Pos2['r']['depth'])[0]
Nrr = np.shape(Pos2['r']['range'])[0]
print ('\nTotal number of receivers : ', Nrr*Nrd)
# Out:
# Total number of receivers :  5010501

# %% [markdown]
# ### Maximum amplitude

# %%
#Dir3, Nb_ref3 = s.direct(Nrr, Nrd, Nsd, Pos3, Arr3)
#np.save(os.path.join('NPY', 'Dir_SSP3'), Dir3)
#np.save(os.path.join('NPY', 'Nb_ref_SSP3'), Nb_ref3)
Dir3 = np.load('NPY/Dir_SSP3.npy')

# %%
s.plot_direct(Pos3, Dir3)

# %% [markdown]
# ### First detected arrival

# %%
RL3_first, Dir3_first, Nb_ref3_first = s.direct_first_arr(Nrr, Nrd, Nsd, Pos3, Arr3, treshold = 10.)
np.save(os.path.join('NPY', 'RL_first_SSP3'), RL3_first)
np.save(os.path.join('NPY', 'Dir_first_SSP3'), Dir3_first)
np.save(os.path.join('NPY', 'Nb_ref_first_SSP3'), Nb_ref3_first)
#Dir3_first = np.load('NPY/Dir_first_SSP3.npy')

# %%
s.plot_direct(Pos3, Dir3_first)

# %% [markdown]
# # SSP4

# %%
issp = 3     # sound speed profile number
s.plotssp('mediterrannee', Issp=issp)

# %%
#### read file .arr 
#Arr4, Pos4 = s.read_arrivals_asc ('files_arr/cognac_2000m_test_A_full_SSP4.arr', Narrmx = 15)
#s.save_dict('Dictio', Arr4, 'Arr4')
#s.save_dict('Dictio', Pos4, 'Pos4')

### reload saved dictionaries 
Arr4, Pos4 = s.load_dict('Dictio', 'Arr4'), s.load_dict('Dictio', 'Pos4')

# %%
Nsd = np.shape(Pos2['s']['depth'])[0]
Nrd = np.shape(Pos2['r']['depth'])[0]
Nrr = np.shape(Pos2['r']['range'])[0]
print ('Total number of receivers : ', Nrr*Nrd)
# Out:
# Total number of receivers :  5010501

# %% [markdown]
# ### Maximum Amplitude

# %%
#Dir4, Nb_ref4 = s.direct(Nrr, Nrd, Nsd, Pos4, Arr4)
#np.save(os.path.join('NPY', 'Dir_SSP4'), Dir4)
#np.save(os.path.join('NPY', 'Nb_ref_SSP4'), Nb_ref4)
Dir4 = np.load('NPY/Dir_SSP4.npy')

# %%
s.plot_direct(Pos4, Dir4)

# %% [markdown]
# ### First detected arrival

# %%
#RL4_first, Dir4_first, Nb_ref4_first = s.direct_first_arr(Nrr, Nrd, Nsd, Pos4, Arr4, treshold = 10.)
#np.save(os.path.join('NPY', 'RL_first_SSP4'), RL4_first)
#np.save(os.path.join('NPY', 'Dir_first_SSP4'), Dir4_first)
#np.save(os.path.join('NPY', 'Nb_ref_first_SSP4'), Nb_ref4_first)
Dir4_first = np.load('NPY/Dir_first_SSP4.npy')

# %%
s.plot_direct(Pos4, Dir4_first)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------
# # Gulf stream - Profile 1

# %%
g = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', 'lon': -66.6, \
                    'lat': 36., 'plot_map': False, 'contour':False}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00060.nc

# %%
issp=0
g.plotssp('gs', Issp=issp)

# %%
Arr_gs_666_36, Pos_gs_666_36 = g.load_dict('Dictio', 'Arr_gs_666_36'), g.load_dict('Dictio', 'Pos_gs_666_36')

# %%
Nsd = np.shape(Pos_gs_666_36['s']['depth'])[0]
Nrd = np.shape(Pos_gs_666_36['r']['depth'])[0]
Nrr = np.shape(Pos_gs_666_36['r']['range'])[0]
print ('Total number of receivers : ', Nrr*Nrd)
# Out:
# Total number of receivers :  5010501

# %% [markdown]
# ### Maximum Amplitude

# %%
#Dir_gs_666_36, Nb_ref_gs_666_36 = g.direct(Nrr, Nrd, Nsd, Pos_gs_666_36, Arr_gs_666_36)
#np.save(os.path.join('NPY', 'Dir_gs_666_36'), Dir_gs_666_36)
#np.save(os.path.join('NPY', 'Nb_ref_gs_666_36'), Nb_ref_gs_666_36)
Dir_gs_666_36 = np.load('NPY/Dir_gs_666_36.npy')

# %%
g.plot_direct(Pos_gs_666_36, Dir_gs_666_36)

# %% [markdown]
# ### First detected arrival

# %%
RL_666_36_first, Dir_666_36_first, Nb_ref_666_36_first = g.direct_first_arr(Nrr, Nrd, Nsd, \
                                                                            Pos_gs_666_36, \
                                                                            Arr_gs_666_36, treshold = 10.)
np.save(os.path.join('NPY', 'RL_first_gs_666_36'), RL_666_36_first)
np.save(os.path.join('NPY', 'Dir_first_gs_666_36'), Dir_666_36_first)
np.save(os.path.join('NPY', 'Nb_ref_first_gs_666_36'), Nb_ref_666_36_first)
#Dir_666_36_first = np.load('NPY/Dir_first_gs_666_36.npy')

# %%
g.plot_direct(Pos_gs_666_36, Dir_666_36_first)

# %% [markdown]
# # Gulf Stream - Profile 2

# %%
g1 = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', 'lon': -61.2, \
                    'lat': 42., 'plot_map': False, 'contour':False}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00060.nc

# %%
g1.plotssp('gs', Issp=issp)

# %%
Arr_gs_612_42, Pos_gs_612_42 = g1.load_dict('Dictio', 'Arr_gs_612_42'), g1.load_dict('Dictio', 'Pos_gs_612_42')

# %%
Nsd = np.shape(Pos_gs_612_42['s']['depth'])[0]
Nrd = np.shape(Pos_gs_612_42['r']['depth'])[0]
Nrr = np.shape(Pos_gs_612_42['r']['range'])[0]
print ('Total number of receivers : ', Nrr*Nrd)
# Out:
# Total number of receivers :  5010501

# %% [markdown]
# ### Maximum amplitude

# %%
#Dir_gs_612_42, Nb_ref_gs_612_42 = g1.direct(Nrr, Nrd, Nsd, Pos_gs_612_42, Arr_gs_612_42)
#np.save(os.path.join('NPY', 'Dir_gs_612_42'), Dir_gs_612_42)
#np.save(os.path.join('NPY', 'Nb_ref_gs_612_42'), Nb_ref_gs_612_42)
Dir_gs_612_42 = np.load('NPY/Dir_gs_612_42.npy')

# %%
g1.plot_direct(Pos_gs_612_42, Dir_gs_612_42)

# %% [markdown]
# ### First detected arrival

# %%
RL_612_42_first, Dir_612_42_first, Nb_ref_612_42_first = g1.direct_first_arr(Nrr, Nrd, Nsd, \
                                                                            Pos_gs_612_42, \
                                                                            Arr_gs_612_42, treshold = 10.)
np.save(os.path.join('NPY', 'RL_first_gs_612_42'), RL_612_42_first)
np.save(os.path.join('NPY', 'Dir_first_gs_612_42'), Dir_612_42_first)
np.save(os.path.join('NPY', 'Nb_ref_first_gs_612_42'), Nb_ref_612_42_first)
#Dir_612_42_first = np.load('NPY/Dir_first_gs_612_42.npy')

# %%
g1.plot_direct(Pos_gs_612_42, Dir_612_42_first)
