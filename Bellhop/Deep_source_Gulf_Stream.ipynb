# %%
# this enable automatic reloading of libraries
# %load_ext autoreload
# %autoreload 2

from clib.flow import *
from clib.bellhop import *

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # Profil 1

# %%
g = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', 'lon': -66.6, \
                    'lat': 36., 'plot_map': True, 'contour':True}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00060.nc

# %%
g.plotssp('gs',y_zoom = 300)

# %% [markdown]
# ## Source à 100m

# %%
g.plot_all(file_ray = 'files/gulf_stream_100m_R.ray', \
           file_shd = 'files/gulf_stream_100m_IB.shd')

# %% [markdown]
# ## Source à 500m

# %%
g.plot_all(file_ray = 'files_gs/gulf_stream_500m_R.ray', \
           file_shd = 'files_gs/gulf_stream_500m_IB.shd')

# %% [markdown]
# ## Source à 1.000m

# %%
g.plot_all(file_ray = 'files_gs/gulf_stream_1000m_R.ray', \
           file_shd = 'files_gs/gulf_stream_1000m_IB.shd')

# %% [markdown]
# ## Source à 1.500m

# %%
g.plot_all(file_ray = 'files_gs/gulf_stream_1500m_R.ray', \
           file_shd = 'files_gs/gulf_stream_1500m_IB.shd')

# %% [markdown]
# # Profil 3

# %%
g1 = bellhop({'gs': {'datadir': '/home/datawork-lops-osi/jgula/NESED/', 'lon': -61.2, \
                    'lat': 42., 'plot_map': True, 'contour':True}}, zmax = 4900)
# Out:
# 1 grid file found, uses: /home/datawork-lops-osi/jgula/NESED/nesea_grd.nc
# -- Grid object
# dim lon_rho: 1602  2002
# lon_rho min= -72.123, max=-58.273
# lat_rho min= 34.123, max=43.734
# h min= 20.000, max=5543.070
# Uses the following output file: /home/datawork-lops-osi/jgula/NESED/nesed_avg.00060.nc

# %%
g1.plotssp('gs',y_zoom = 300)

# %% [markdown]
# ## Source à 100m

# %%
g1.plot_all(file_ray = 'files/gulf_stream_612_42_100m_R.ray', \
           file_shd = 'files/gulf_stream_612_42_100m_IB.shd')

# %% [markdown]
# ## Source à 500m

# %%
g1.plot_all(file_ray = 'files_gs/gulf_stream_612_42_500m_R.ray', \
           file_shd = 'files_gs/gulf_stream_612_42_500m_IB.shd')

# %% [markdown]
# ## Source à 1.000m

# %%
g1.plot_all(file_ray = 'files_gs/gulf_stream_612_42_1000m_R.ray', \
           file_shd = 'files_gs/gulf_stream_612_42_1000m_IB.shd')
