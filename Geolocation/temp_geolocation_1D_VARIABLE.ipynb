# %% [markdown]
# #  Geolocalisation 1D avec e_tp variable (Partie 4.7.2)
#
# ---
# ---
#
# Au lieu de chercher à déterminer une erreur moyenne sur le temps de propagation (e_tp), l'idée est de travailler avec une erreur variable selon la distance qui sépare le récepteur et la source. En effet, plus le récepteur est proche d'une source, plus l'erreur est faible.
#
# Dans l’exemple étudié dans la partie 4.6, au large du Golfe de Gascogne, nous pouvons définir trois zones distinctes :
#
# — distance inférieure à 15 km : l’erreur est très faible, d’environ 10m (soit 7ms).
#
# — distance entre 15 et 60km : l’erreur est plutôt aux alentours de 150m (soit 100ms).
#
# — distance supérieure à 60km : erreur très importante , d'environ 500m (soit 327ms).
#
# ---
# ---

# %%
# this enable automatic reloading of libraries
# %load_ext autoreload
# %autoreload 2

# import libraries
import numpy as np
import matplotlib.pyplot as plt
from clib.geolocation_1D import *

# %% [markdown]
# ---
# ---
# # 1 - Création d'un ensemble de 3 sources

# %%
### create an ensemble of sources
dx=50. *1.e3 # in meters
sources3=[]
sources3.append(source( dx*0., 0))
sources3.append(source(-dx*.8, 0))
sources3.append(source( dx*.8, 0))
Ns = len(sources3)

# init a receiver
#r=receiver(-30. *1.e3, 0, e_x=10.e3, e_dt=0.)

### plot
plt.figure(figsize=(8,1.5))
ax=plt.subplot(111)
[s.plot() for s in sources3]
#r.plot()
plt.ylim([-3, 3])
plt.xlim([-60.,60.])
ax.grid()
ax.set_aspect('equal')
ax.get_yaxis().set_visible(False)
plt.xlabel('x (km)')
plt.show()

# %% [markdown]
# **- Incertitudes a priori : **

# %%
print("e_dx  = %.1f m     (uncertainty on transducer position)" %sources[0].e_dx)
print("e_x   = %.1f m  (uncertainty on underwater float position)" %r.e_x)
# Out:
# e_dx  = 10.0 m     (uncertainty on transducer position)
# e_x   = 10000.0 m  (uncertainty on underwater float position)

# %% [markdown]
# **- Variables inchangées durant les simulations :  **

# %%
print("s.x_t :", [s.x_t for s in sources3])   # due to uncertainty on transducer position 
print("s.dx  :", [s.dx for s in sources3])
# Out:
# s.x_t : [array([-19.24671593]), array([-40003.79830855]), array([39989.64080331])]
# s.dx  : [array([-19.24671593]), array([-3.79830855]), array([-10.35919669])]

# %% [markdown]
# ---
# ---
# ---
# # 2 - Fonction de cacluls et de tracé des transects

# %% [markdown]
# **- Function "simu" : simulations pour 1 position de récepteur. Renvoie les rms et biais.  **

# %%
def simu (r, sources, Nmc, var, t_drift) : 
    ''' It returns rms and bias on x position for one receiver position'''
    x=np.zeros(Nmc)
    y=np.zeros(Nmc)
    dt=np.zeros(Nmc)
    su = np.zeros (Nmc)
    
    for i in range(Nmc):
        
        if var == 'celerity' : 
            [s.draw_celerity(s.e_c) for s in sources]
        if var == 'dxdy' : 
            [s.draw_dxdy(10.) for s in sources]
        if var == 'clock' : 
            r.draw_clock_drift()
            #dt_truth[i] = r.dt    
        
        # solve a first time
        r.t_r_tilda = np.array([s.t_e+pmap.draw_t(dist(s,r))+r.dt for s in sources]).squeeze()
        x[i], dt[i], success, message, res = geolocalize_xtmap_1D(r, sources, pmap, clock_drift=t_drift, \
                                                                  x0 = [-150000.,0])
        # rerun with adjusted expected errors on propagation time
        for j in range(1):
            x[i], dt[i], success, message, res = geolocalize_xtmap_1D(r, sources, pmap, \
                                                                         clock_drift=t_drift, \
                                                                         x0=[x[i], dt[i]])        
        if success :
            su[i] = 1 
        elif message.find('iterations')!= -1 : 
            # "Warning: Maximum number of iterations has been exceeded."
            su[i] = -1
        elif message.find('precision loss')!= -1 :
            #Warning: Desired error not necessarily achieved due to precision loss.
            su[i] = -2
        else : 
            su[i] = -3
    
    
    # rms error on the receiver position
    d_rms = np.sqrt( np.mean( (x[np.where(su==1)] - r.x)**2 ) )
    # biais on the receiver position
    bias_x = x[np.where(su==1)].mean()-r.x
    bias_y = y[np.where(su==1)].mean()-r.y
    #print('x[np.where(su==1)].mean() :' , x[np.where(su==1)].mean())
    #print('r.x : ', r.x)
    return (d_rms, bias_x, su)

# %% [markdown]
# **- Fonctions de calculs et tracés pour les transects : **

# %%
from ipywidgets import FloatProgress
from IPython.display import display


def transect (sources, X, Y, Nmc, var, clock_drift = False, e_dt=0.01) :
    RMS_t = np.zeros((len(X)))
    BiasX_t = np.zeros((len(X)))
    Success_t = np.zeros((Nmc, len(X)))
    
    r = receiver(X[0], Y, e_dt=e_dt)
    r_dt = r.dt
    
    f = FloatProgress(value = 0., min=0., max=100., step=1., orientation='horizontal', description = 'Loading :')
    display(f)
    
    for i in range (len(X)) :
        
        f.value = i/len(X)*100.

        # init a receiver
        r = receiver(X[i], Y, e_dt=e_dt)
        #print('position réelle r : ', r.x)
        #r.dt = r_dt # unchanged variable during simulations 
        #
        d_rms, bias_x, su = simu (r, sources, Nmc, var = var, t_drift = clock_drift)

        RMS_t[i]       = d_rms
        BiasX_t[i]     = bias_x
        Success_t[:,i] = su

    f.value = 100.
    
    return RMS_t, BiasX_t, Success_t


def plot_transect (sources, X, Y, RMS_t, Biais_t):
    print('mean (rms) = %.1fm  /// max (rms) = %.1f m' % (np.mean(RMS_t), np.max(RMS_t)))
    print('mean (bias) = %.1fm /// max (bias) = %.1f m' % (np.mean(Biais_t), np.max(Biais_t)))
    plt.figure(figsize=(17,4))
    # plot sources 
    ax=plt.subplot(131)
    [s.plot() for s in sources]
    plt.title ('sources and transect')
    plt.xlabel('x [km]')
    plt.ylabel('y [km]')
    ax.grid()
    #ax.set_xlim([np.min(X)/1000.,np.max(X)/1000.])
    ax.set_ylim([-abs(sources[0].y_s)/1000. - 5., abs(sources[0].y_s)/1000. + 5.])
    ax.set_aspect('equal')
    plt.plot([np.min(X)/1000.,np.max(X)/1000.],[Y/1000.,Y/1000.],'.-b')

    ## plot rms result
    ax2 = plt.subplot(132)
    ax2.grid()
    plt.plot(X/1.e3, RMS_t, '.') 
    plt.xlabel('x [km]')
    plt.ylabel('RMS [m]')
    plt.title('RMS error' )
    
    ## plot bias
    ax3  = plt.subplot(133)
    ax3.grid()
    plt.plot(X/1.e3, Biais_t, '.')
    plt.xlabel('x [km]')
    plt.ylabel('Bias [m]')
    plt.title('Bias on x ' )
    
    plt.show()

# %% [markdown]
# ---
# ---
# # 3 - Initialisation du mapping (avec l'erreur e_tp variable)

# %%
### Position des sources
[s.x_s for s in sources3]
# Out:
# [0.0, -40000.0, 40000.0]

# %%
### Fonction définissant la variabilité de e_tp
def func_var(dist) : 
    if dist < 15000. :
        return 0.007   # 10m soit 7ms
    if np.logical_and(dist>=15000, dist <60000.) :
        return 0.1     # 150m soit 100ms
    else : 
        return 0.327   # 490m soit 327ms

# %%
### Initialisation du mapping
pmap = xtmap(c_b=1500., e_c=0., e_t=func_var, e_min=1.e-3)
#pmap = xtmap(c_b=1500., e_c=0., e_t=0.1, e_min=1.e-3)

# %%
### Plot des erreurs en fonction des posiitons des sources
plt.figure(figsize=(8,5))
xx = np.arange(0,150000,1000)
plot_etp = np.array([pmap.e_tp(x) for x in xx])

plt.plot(xx/1000.,plot_etp, '.', label='erreur e_tp')
plt.title('Erreur e_tp variable selon la distance source-récepteur', fontsize=16)
plt.xlabel('x (km)', fontsize=14)
plt.ylabel('erreur e_tp (s)', fontsize=14)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.plot(sources3[0].x_s/1.e3, -0.02, color='darkorange', marker='o', markersize=13, \
         label='position de la source')
plt.plot([sources3[0].x_s/1.e3,sources3[0].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')

plt.xlim([-5,100.])
plt.ylim([-0.03,0.36])
plt.legend(fontsize=13, facecolor='lightgrey')
plt.grid()

plt.savefig('erreur_variable', dpi=100)

# %% [markdown]
# ---
# ---
#
# # 3 - Calcul des résultats sur un transect

# %%
### Création du transect
L = 120.* 1.e3
X = np.linspace(-L/2.,L/2.,241)  # resolution : 500m
Y = 0.

# %% [markdown]
# ---
# #### Résultats avec e_tp variable et une dérive de 26ms

# %%
Nmc = 100          # number of simulations
var = 'celerity'   # only celerity is varying
RMS_t, BiasX_t, Success_t = transect (sources3, X, Y, Nmc, var, clock_drift = True, e_dt=0.026 )
# Out:
# FloatProgress(value=0.0, description='Loading :')
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-33.49568259,   0.14958789],
#        [-33.4973182 ,   0.14893969],
#        [-33.49568259,   0.14829276]]), array([0.19808008, 0.1998155 , 0.20070658]))
#            fun: 0.19808008418651793
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-33.49568259,   0.14958789])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-3.20066137e+01, -2.28992328e-02],
#        [-3.20058322e+01, -2.27997195e-02],
#        [-3.20066137e+01, -2.27001090e-02]]), array([2.47647609, 2.47745803, 2.47832982]))
#            fun: 2.4764760882305104
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-3.20066137e+01, -2.28992328e-02])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[29.00208916, -0.94376678],
#        [28.9964258 , -0.93973203],
#        [29.00208916, -0.93566564]]), array([2.46433692, 2.48225028, 2.49808865]))
#            fun: 2.4643369178307295
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([29.00208916, -0.94376678])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations

# %%
plot_transect(sources3, X, Y, RMS_t, BiasX_t)
# Out:
# mean (rms) = 36.0m  /// max (rms) = 155.4 m
# mean (bias) = 0.2m /// max (bias) = 106.9 m

# %%
### RMS et biais à l'intérieur des sources (entre -40 et +40km)
print(np.mean(RMS_t[41:200]))
print(np.max(RMS_t[41:200]))
print(np.mean(BiasX_t[41:200]))
print(np.max(abs(BiasX_t[41:200])))
# Out:
# 27.87969198988549
# 102.48313073745922
# -0.250149312547322
# 20.758057577040745

# %%
np.save('RMS_variable_26ms', RMS_t)
np.save('BIAS_variable_26ms', BiasX_t)

# %%
plt.figure(figsize=(16,5))
## plot rms result
ax2 = plt.subplot(121)
ax2.grid()
plt.plot(X/1.e3, RMS_t, '.') 
plt.xlabel('x [km]', fontsize=14)
plt.ylabel('RMS [m]', fontsize=14)
plt.title('Erreur sur la position du flotteur - Sans dérive', fontsize=16 )

plt.plot(sources3[0].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12)
plt.plot(sources3[1].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12)
plt.plot(sources3[2].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12, label='source')
plt.plot([sources3[0].x_s/1.e3,sources3[0].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')
plt.plot([sources3[1].x_s/1.e3,sources3[1].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')
plt.plot([sources3[2].x_s/1.e3,sources3[2].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')

plt.legend(fontsize=12)

## plot bias
ax3  = plt.subplot(122)
ax3.grid()
plt.plot(X/1.e3, BiasX_t, '.')

plt.xlabel('x [km]', fontsize=14)
plt.ylabel('biais [m]', fontsize=14)
plt.title('Biais sur la position du flotteur - Sans dérive', fontsize=16)

plt.savefig('transect_0', dpi=100)

# %%
#### Il faut que e_tp soit différent pour chaque source dans la somme de la minimisation....

# %%
[s.x_s for s in sources3]
# Out:
# [0.0, -40000.0, 40000.0]

# %%
### On fixe x0 = -150000. pour avoir une erreur constante sur e_tp lors des Nmc simulations.
### Puis à la dernière simu, x0 est réajusté et les poids des erreurs changent alors.

# %%
###### AVEC ERREUR VARIABLE

Nmc = 100          # number of simulations
var = 'celerity'   # only celerity is varying
RMS_t, BiasX_t, Success_t = transect (sources3, X, Y, Nmc, var, clock_drift = True, e_dt=0.026 )
# Out:
# FloatProgress(value=0.0, description='Loading :')
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-4.58139747e+01, -4.12581450e-04],
#        [-4.58134155e+01, -4.09774093e-04],
#        [-4.58139747e+01, -4.06968106e-04]]), array([108.82701781, 108.82701791, 108.82701827]))
#            fun: 108.82701781478634
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-4.58139747e+01, -4.12581450e-04])
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-4.58657091e+01, -2.45337158e-04],
#        [-4.58659890e+01, -2.43656973e-04],
#        [-4.58657091e+01, -2.41976378e-04]]), array([109.17824974, 109.17824991, 109.17825001]))
#            fun: 109.17824973744602
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-4.58657091e+01, -2.45337158e-04])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-2.46050366e+01, -1.52115304e-02],
#        [-2.46038352e+01, -1.51457437e-02],
#        [-2.46050366e+01, -1.50798283e-02]]), array([0.2430034 , 0.24301155, 0.24301479]))
#            fun: 0.2430034005783778
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-2.46050366e+01, -1.52115304e-02])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-23.98342426,   0.20207964],
#        [-23.98181422,   0.19381929],
#        [-23.980131  ,   0.20296518]]), array([1.31297653, 1.31306061, 1.31319923]))
#            fun: 1.3129765287072053
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 400
#            nit: 201
#         status: 1
#        success: False
#              x: array([-23.98342426,   0.20207964])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-2.38484446e+01, -1.16954658e-03],
#        [-2.38481535e+01, -1.16158855e-03],
#        [-2.38484446e+01, -1.15363440e-03]]), array([159.57306261, 159.57306267, 159.57306282]))
#            fun: 159.57306261095968
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-2.38484446e+01, -1.16954658e-03])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-2.34450663e+01, -1.66520348e-02],
#        [-2.34439216e+01, -1.65800182e-02],
#        [-2.34450663e+01, -1.65078608e-02]]), array([1.64096585, 1.64098336, 1.64099571]))
#            fun: 1.6409658490406076
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-2.34450663e+01, -1.66520348e-02])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-22.98482096,   0.02482358],
#        [-22.98369871,   0.02471622],
#        [-22.98482096,   0.02460865]]), array([0.25460645, 0.25461557, 0.25463091]))
#            fun: 0.25460645351479416
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-22.98482096,   0.02482358])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-22.42610439,   0.02713033],
#        [-22.42500942,   0.027013  ],
#        [-22.42610439,   0.02689543]]), array([0.07970372, 0.07970758, 0.07971934]))
#            fun: 0.07970372436308233
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-22.42610439,   0.02713033])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-21.11832344,   0.02310081],
#        [-21.1162611 ,   0.02300143],
#        [-21.11832344,   0.02290167]]), array([0.60589777, 0.6059104 , 0.60594155]))
#            fun: 0.6058977652990637
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-21.11832344,   0.02310081])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-2.05153949e+01, -1.71219232e-02],
#        [-2.05148940e+01, -1.70475164e-02],
#        [-2.05153949e+01, -1.69730369e-02]]), array([0.01808378, 0.01808586, 0.01808619]))
#            fun: 0.01808377754429088
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-2.05153949e+01, -1.71219232e-02])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-2.07842523e+01, -1.54113013e-02],
#        [-2.07801937e+01, -1.53454157e-02],
#        [-2.07842523e+01, -1.52790133e-02]]), array([1.84246234, 1.84250981, 1.84251221]))
#            fun: 1.8424623357290868
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-2.07842523e+01, -1.54113013e-02])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-2.07639245e+01, -8.02536194e-03],
#        [-2.07629107e+01, -7.99065390e-03],
#        [-2.07639245e+01, -7.95587800e-03]]), array([167.42629112, 167.42629185, 167.42629275]))
#            fun: 167.42629112163175
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-2.07639245e+01, -8.02536194e-03])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-19.92064289,   0.02760987],
#        [-19.91869751,   0.02749109],
#        [-19.92064289,   0.02737185]]), array([0.48242241, 0.48244049, 0.48247334]))
#            fun: 0.48242241157495164
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-19.92064289,   0.02760987])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-18.61444447,   0.21301521],
#        [-18.61457047,   0.21097425],
#        [-18.61416839,   0.21025878]]), array([1.55857537, 1.55857673, 1.55858191]))
#            fun: 1.5585753666299036
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 203
#         status: 1
#        success: False
#              x: array([-18.61444447,   0.21301521])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-18.42819053,   0.19513579],
#        [-18.42821024,   0.19511614],
#        [-18.4282119 ,   0.19545027]]), array([3.09124551, 3.09124552, 3.09124556]))
#            fun: 3.0912455120776317
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 400
#            nit: 202
#         status: 1
#        success: False
#              x: array([-18.42819053,   0.19513579])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[-1.43548857e+01, -2.15346251e-03],
#        [-1.43541848e+01, -2.14414922e-03],
#        [-1.43548857e+01, -2.13481773e-03]]), array([184.45194408, 184.45194452, 184.45194495]))
#            fun: 184.45194407694927
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([-1.43548857e+01, -2.15346251e-03])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[17.51143866, -0.09942597],
#        [17.50475902, -0.1470126 ],
#        [17.50536383, -0.1140851 ]]), array([0.99601146, 0.99622199, 1.00004323]))
#            fun: 0.9960114639374921
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 400
#            nit: 202
#         status: 1
#        success: False
#              x: array([17.51143866, -0.09942597])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[18.51856514, -0.07224243],
#        [18.52498912, -0.05636918],
#        [18.52370291, -0.04251016]]), array([1.17014588, 1.17211181, 1.17759594]))
#            fun: 1.170145883977008
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 400
#            nit: 201
#         status: 1
#        success: False
#              x: array([18.51856514, -0.07224243])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[20.6064368 , -0.02550329],
#        [20.60844915, -0.02539315],
#        [20.6064368 , -0.02528344]]), array([0.46572501, 0.46573937, 0.46577107]))
#            fun: 0.465725005995636
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([20.6064368 , -0.02550329])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[21.39968922, -0.02614636],
#        [21.40177904, -0.02603344],
#        [21.39968922, -0.02592096]]), array([1.28109479, 1.28111476, 1.28113519]))
#            fun: 1.2810947894558056
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([21.39968922, -0.02614636])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[21.93505348, -0.02875747],
#        [21.93719558, -0.02863328],
#        [21.93505348, -0.02850956]]), array([0.57630088, 0.57633532, 0.576368  ]))
#            fun: 0.576300877043868
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([21.93505348, -0.02875747])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[22.59714018, -0.05300028],
#        [22.59724362, -0.03968876],
#        [22.59593334, -0.04050311]]), array([0.22712445, 0.22733907, 0.22735908]))
#            fun: 0.22712444554762154
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 202
#         status: 1
#        success: False
#              x: array([22.59714018, -0.05300028])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[23.62062381, -0.02932056],
#        [23.62523811, -0.02919423],
#        [23.62062381, -0.02906888]]), array([0.39250097, 0.3925076 , 0.39255435]))
#            fun: 0.39250096712535426
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([23.62062381, -0.02932056])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[24.9855225 , -0.06423362],
#        [24.98796249, -0.06395621],
#        [24.9855225 , -0.06367988]]), array([0.32849722, 0.32851932, 0.32855224]))
#            fun: 0.32849721548510036
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([24.9855225 , -0.06423362])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[25.46171731, -0.02853773],
#        [25.46296062, -0.02841407],
#        [25.46171731, -0.02829065]]), array([0.51013697, 0.51014224, 0.5101557 ]))
#            fun: 0.5101369721908746
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([25.46171731, -0.02853773])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[39.99974686, -0.44861841],
#        [40.00023514, -0.4466589 ],
#        [39.99974686, -0.44470035]]), array([2.60132927, 2.60658517, 2.61443806]))
#            fun: 2.60132926936862
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([39.99974686, -0.44861841])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[39.99987733, -0.25471419],
#        [40.00012147, -0.25359689],
#        [39.99987733, -0.25247986]]), array([1.90303228, 1.90809508, 1.91403114]))
#            fun: 1.9030322790974807
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([39.99987733, -0.25471419])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[ 3.99999694e+01, -2.71105950e-02],
#        [ 4.00000304e+01, -2.69906329e-02],
#        [ 3.99999694e+01, -2.68706782e-02]]), array([1.67069172, 1.6714582 , 1.67185927]))
#            fun: 1.6706917172278275
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([ 3.99999694e+01, -2.71105950e-02])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[39.99988139, -0.39895693],
#        [40.00012553, -0.3972069 ],
#        [39.99988139, -0.39545731]]), array([2.56876155, 2.5794289 , 2.58498549]))
#            fun: 2.568761552810933
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([39.99988139, -0.39895693])
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[39.99975612, -0.54301188],
#        [40.00024441, -0.54064007],
#        [39.99975612, -0.53826942]]), array([2.15081518, 2.15920678, 2.17111151]))
#            fun: 2.150815181541041
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([39.99975612, -0.54301188])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[ 3.99999925e+01, -2.69382422e-02],
#        [ 4.00000077e+01, -2.68179813e-02],
#        [ 3.99999925e+01, -2.66977222e-02]]), array([2.70902423, 2.70988577, 2.71062773]))
#            fun: 2.709024228188602
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 200
#         status: 1
#        success: False
#              x: array([ 3.99999925e+01, -2.69382422e-02])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# Still no convergence
#  final_simplex: (array([[39.99999996, -0.57712866],
#        [40.00000004, -0.57662582],
#        [40.00000024, -0.57728109]]), array([0.5934163 , 0.59341719, 0.59342244]))
#            fun: 0.5934162994400249
#        message: 'Maximum number of function evaluations has been exceeded.'
#           nfev: 401
#            nit: 203
#         status: 1
#        success: False
#              x: array([39.99999996, -0.57712866])
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations
# No convergence, try with 1000 more iterations

# %%
plt.figure(figsize=(16,5))
## plot rms result
ax2 = plt.subplot(121)
ax2.grid()
plt.plot(X/1.e3, RMS_t, '.') 
plt.xlabel('x [km]', fontsize=14)
plt.ylabel('RMS [m]', fontsize=14)
plt.title('Erreur sur la position du flotteur - Sans dérive', fontsize=16 )

plt.plot(sources3[0].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12)
plt.plot(sources3[1].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12)
plt.plot(sources3[2].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12, label='source')
plt.plot([sources3[0].x_s/1.e3,sources3[0].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')
plt.plot([sources3[1].x_s/1.e3,sources3[1].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')
plt.plot([sources3[2].x_s/1.e3,sources3[2].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')

plt.legend(fontsize=12)

## plot bias
ax3  = plt.subplot(122)
ax3.grid()
plt.plot(X/1.e3, BiasX_t, '.')

plt.xlabel('x [km]', fontsize=14)
plt.ylabel('biais [m]', fontsize=14)
plt.title('Biais sur la position du flotteur - Sans dérive', fontsize=16)

plt.savefig('transect_0', dpi=100)

# %%
plt.figure(figsize=(8,5))
## plot rms result
ax2 = plt.subplot(111)
ax2.grid()
plt.plot(X/1.e3, RMS_t, '.') 
plt.xlabel('x [km]', fontsize=14)
plt.ylabel('RMS [m]', fontsize=14)
plt.title('Erreur sur la position du flotteur - Sans dérive', fontsize=16 )

plt.plot(sources3[0].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12)
plt.plot(sources3[1].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12)
plt.plot(sources3[2].x_s/1.e3, -0.03, color='darkorange', marker='o', markersize=12, label='source')
plt.plot([sources3[0].x_s/1.e3,sources3[0].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')
plt.plot([sources3[1].x_s/1.e3,sources3[1].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')
plt.plot([sources3[2].x_s/1.e3,sources3[2].x_s/1.e3],[-0.05,0.40],'--', color='darkorange')

plt.ylim([-10, 250])
plt.legend(fontsize=12)
